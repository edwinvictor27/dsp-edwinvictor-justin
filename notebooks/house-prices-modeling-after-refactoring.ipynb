# %% [markdown]
# # **Installing Pre-requisites for our Analysis**

# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install pyarrow

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from IPython.display import display

# %% [markdown]
# ## **Storing the dataset in a variable**

# %%
dataset_for_training = r"C:/Users/edwin victor/git repositories/dsp-edwinvictor-justin/data/train.csv"

# %% [markdown]
# # **Reading the csv file using read_csv function**

# %%
Training_dataset = pd.read_csv(dataset_for_training)
display(Training_dataset)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # **Analyzing the dataset to get overview using some commonly used pandas functions**

# %%
display(Training_dataset.head(5))
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
display(Training_dataset.tail(5))
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
display(Training_dataset.columns) #to get names of the columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
Training_dataset.shape()  #totally there are 1460 rows and 81 columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Training_dataset.shape()
#
# TypeError: 'tuple' object is not callable

# %%
display(Training_dataset.shape) #totally there are 1460 rows and 81 columns
# Out:
# (1460, 81)

# %%
display(Training_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
display(Training_dataset.isnull('SalePrice').sum()) # to get total null values in a column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 display(Training_dataset.isnull('SalePrice').sum())
#
# TypeError: isnull() takes 1 positional argument but 2 were given

# %%
display(Training_dataset.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ## **DATA PRE-PROCESSING for the purpose of training the model**

# %%
selected_features = ['LotArea', 'GrLivArea', 'Neighborhood', 'HouseStyle'] # 2 continuos and 2 Categorical features
target_feature = ['SalePrice'] #Output column

# %%
continuos_datatype_features = ['LotArea', 'GrLivArea']
discrete_datatype_features = ['Neighborhood', 'HouseStyle']

# %%
Extracted_Selected_Features = Training_dataset[selected_features]
Extracted_Target_Attribute = Training_dataset[target_feature]

# %%
Extracted_selected_Features.isnull().sum() #checking if there's any null value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 Extracted_selected_Features.isnull().sum()
#
# NameError: name 'Extracted_selected_Features' is not defined

# %%
Extracted_Selected_Features.isnull().sum() #checking if there's any null value
# Out:
# LotArea         0
# GrLivArea       0
# Neighborhood    0
# HouseStyle      0
# dtype: int64

# %%
Extracted_Target_Attribute.isnull().sum()
# Out:
# SalePrice    0
# dtype: int64

# %%
Merged_Features = pd.concat([Extracted_Selected_Features,Extracted_Target_Attribute], axis=1)
display(Merged_Features) #concatenating selected features together as single dataframe
# Out:
#       LotArea  GrLivArea Neighborhood HouseStyle  SalePrice
# 0        8450       1710      CollgCr     2Story     208500
# 1        9600       1262      Veenker     1Story     181500
# 2       11250       1786      CollgCr     2Story     223500
# 3        9550       1717      Crawfor     2Story     140000
# 4       14260       2198      NoRidge     2Story     250000
# ...       ...        ...          ...        ...        ...
# 1455     7917       1647      Gilbert     2Story     175000
# 1456    13175       2073       NWAmes     1Story     210000
# 1457     9042       2340      Crawfor     2Story     266500
# 1458     9717       1078        NAmes     1Story     142125
# 1459     9937       1256      Edwards     1Story     147500
#
# [1460 rows x 5 columns]

# %%
Merged_Features[discrete_datatype_features].nunique() #to get the count of different values from the categorical data type column
# Out:
# Neighborhood    25
# HouseStyle       8
# dtype: int64

# %%
encoded_discrete_features_df = pd.get_dummies(Merged_Features[discrete_datatype_features])
display(encoded_discrete_features_df) 

# performing one hot encoding for the selected discrete(categorical) features 

# cross-verifying the dimension matches with the above unique values [33 unique values hence 33 columns]
# Out:
#       Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0                    False                 False                False
# 1                    False                 False                False
# 2                    False                 False                False
# 3                    False                 False                False
# 4                    False                 False                False
# ...                    ...                   ...                  ...
# 1455                 False                 False                False
# 1456                 False                 False                False
# 1457                 False                 False                False
# 1458                 False                 False                False
# 1459                 False                 False                False
#
#       Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# ...

# %% [markdown]
# # **Scaling columns that has continuos data types (LotArea, GrLivArea)**

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(merged_attributes[continuos_datatype_col])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 scaler.fit_transform(merged_attributes[continuos_datatype_col])
#
# NameError: name 'continuos_datatype_col' is not defined

# %%
Extracted_Continuos_Datatype_Features = Merged_Features[continuos_datatype_features]
scaled_continuous_features = scaler.fit_transform(Extracted_Continuos_Datatype_Features)
scaled_continuous_features_df = pd.DataFrame(scaled_continuous_features, columns= continuos_datatype_features)
display(scaled_continuous_features_df)
# Out:
#        LotArea  GrLivArea
# 0    -0.207142   0.370333
# 1    -0.091886  -0.482512
# 2     0.073480   0.515013
# 3    -0.096897   0.383659
# 4     0.375148   1.299326
# ...        ...        ...
# 1455 -0.260560   0.250402
# 1456  0.266407   1.061367
# 1457 -0.147810   1.569647
# 1458 -0.080160  -0.832788
# 1459 -0.058112  -0.493934
#
# [1460 rows x 2 columns]

# %%
processed_df_1 = pd.concat([scaled_continuous_features_df , encoded_discrete_features_df ], axis=1)
processed_df = pd.concat([processed_df_1,Extracted_Target_Attribute], axis=1)
display(processed_df.head(5))
display(processed-df.shape)
# Out:
#     LotArea  GrLivArea  Neighborhood_Blmngtn  Neighborhood_Blueste  \
# 0 -0.207142   0.370333                 False                 False
# 1 -0.091886  -0.482512                 False                 False
# 2  0.073480   0.515013                 False                 False
# 3 -0.096897   0.383659                 False                 False
# 4  0.375148   1.299326                 False                 False
#
#    Neighborhood_BrDale  Neighborhood_BrkSide  Neighborhood_ClearCr  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_CollgCr  Neighborhood_Crawfor  Neighborhood_Edwards  ...  \
# 0                  True                 False                 False  ...
# ...

# %%
processed_df_1 = pd.concat([scaled_continuous_features_df , encoded_discrete_features_df ], axis=1)
processed_df = pd.concat([processed_df_1,Extracted_Target_Attribute], axis=1)
display(processed_df.head(5))
display(processed_df.shape)
# Out:
#     LotArea  GrLivArea  Neighborhood_Blmngtn  Neighborhood_Blueste  \
# 0 -0.207142   0.370333                 False                 False
# 1 -0.091886  -0.482512                 False                 False
# 2  0.073480   0.515013                 False                 False
# 3 -0.096897   0.383659                 False                 False
# 4  0.375148   1.299326                 False                 False
#
#    Neighborhood_BrDale  Neighborhood_BrkSide  Neighborhood_ClearCr  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_CollgCr  Neighborhood_Crawfor  Neighborhood_Edwards  ...  \
# 0                  True                 False                 False  ...
# ...

# %% [markdown]
# # **Training the Model using the after the selected features is processed and prepared**

# %%
X = processed_df.drop(columns= target_feature )  
y = processed_df[target_feature]

# %%
model = LinearRegression() #training the model with linear regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=50)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # checking accuracy of our model

# %%
Rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred)) #rmse = root mean squared error
print ("Root Mean Squared Error:", Rmsle * 100) #using rmse metric to check how good our model has performed
# Out:
# Root Mean Squared Error: 19.12028656482006

# %% [markdown]
# ## **Storing the processed dataframe as parquet file**

# %%
# processed_df.to_parquet('C:/Users/edwin victor/git repositories/dsp-edwinvictor-justin/data/house_price_modeling_processed_df.parquet', index = False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 processed_df.to_parquet('C:/Users/edwin victor/git repositories/dsp-edwinvictor-justin/data/house_price_modeling_processed_df.parquet', index = False)
#
# File D:\miniconda\miniconda\envs\ml\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File D:\miniconda\miniconda\envs\ml\lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
# ...

# %%
# !pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.1 MB 991.0 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/25.1 MB 787.7 kB/s eta 0:00:32
#    ---------------------------------------- 0.2/25.1 MB 1.5 MB/s eta 0:00:17
#    ---------------------------------------- 0.3/25.1 MB 1.6 MB/s eta 0:00:16
#     --------------------------------------- 0.4/25.1 MB 2.0 MB/s eta 0:00:13
#     --------------------------------------- 0.6/25.1 MB 2.2 MB/s eta 0:00:12
#    - -------------------------------------- 0.7/25.1 MB 2.3 MB/s eta 0:00:11
#    - -------------------------------------- 1.0/25.1 MB 2.8 MB/s eta 0:00:09
#    - -------------------------------------- 1.1/25.1 MB 2.9 MB/s eta 0:00:09
#    -- ------------------------------------- 1.3/25.1 MB 2.9 MB/s eta 0:00:09
#    -- ------------------------------------- 1.5/25.1 MB 3.1 MB/s eta 0:00:08
# ...

# %%
# actual_processed_df = processed_df.to_parquet('C:/Users/edwin victor/git repositories/dsp-edwinvictor-justin/data/house_price_modeling_processed_df.parquet', index = False)

# %%
expected_processed_df = pd.read_parquet('C:/Users/edwin victor/git repositories/dsp-edwinvictor-justin/data/house_price_modeling_processed_df.parquet')
expected_processed_df
# Out:
#        LotArea  GrLivArea  Neighborhood_Blmngtn  Neighborhood_Blueste  \
# 0    -0.207142   0.370333                 False                 False
# 1    -0.091886  -0.482512                 False                 False
# 2     0.073480   0.515013                 False                 False
# 3    -0.096897   0.383659                 False                 False
# 4     0.375148   1.299326                 False                 False
# ...        ...        ...                   ...                   ...
# 1455 -0.260560   0.250402                 False                 False
# 1456  0.266407   1.061367                 False                 False
# 1457 -0.147810   1.569647                 False                 False
# 1458 -0.080160  -0.832788                 False                 False
# 1459 -0.058112  -0.493934                 False                 False
#
#       Neighborhood_BrDale  Neighborhood_BrkSide  Neighborhood_ClearCr  \
# ...

# %%
pd.testing.assert_frame_equal(actual_processed_df, expected_processed_df)
